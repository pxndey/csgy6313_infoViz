# %%
# !pip install fastf1
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 13.9 MB/s  0:00:00 13.9 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 15.0 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/11 [fastf1]━━━━━━━━━  6/11 [cryptography]
# ...

# %%
import fastf1 as f1

# %%
session25 = f1.get_event_schedule(2025)

# %%
session24 = f1.get_event_schedule(2022)

# %%
session24.head()
# Out:
#    RoundNumber       Country   Location  \
# 0            0         Spain      Spain
# 1            0       Bahrain    Bahrain
# 2            1       Bahrain     Sakhir
# 3            2  Saudi Arabia     Jeddah
# 4            3     Australia  Melbourne
#
#                                OfficialEventName  EventDate  \
# 0        FORMULA 1 PRE-SEASON TRACK SESSION 2022 2022-02-25
# 1       FORMULA 1 ARAMCO PRE-SEASON TESTING 2022 2022-03-12
# 2     FORMULA 1 GULF AIR BAHRAIN GRAND PRIX 2022 2022-03-20
# 3    FORMULA 1 STC SAUDI ARABIAN GRAND PRIX 2022 2022-03-27
# 4  FORMULA 1 HEINEKEN AUSTRALIAN GRAND PRIX 2022 2022-04-10
#
#                   EventName   EventFormat    Session1  \
# 0  Pre-Season Track Session       testing  Practice 1
# 1           Pre-Season Test       testing  Practice 1
# 2        Bahrain Grand Prix  conventional  Practice 1
# 3  Saudi Arabian Grand Prix  conventional  Practice 1
# 4     Australian Grand Prix  conventional  Practice 1
#
# ...

# %%
session25.head()
# Out:
#    RoundNumber    Country   Location  \
# 0            0    Bahrain     Sakhir
# 1            1  Australia  Melbourne
# 2            2      China   Shanghai
# 3            3      Japan     Suzuka
# 4            4    Bahrain     Sakhir
#
#                                    OfficialEventName  EventDate  \
# 0           FORMULA 1 ARAMCO PRE-SEASON TESTING 2025 2025-02-28
# 1  FORMULA 1 LOUIS VUITTON AUSTRALIAN GRAND PRIX ... 2025-03-16
# 2         FORMULA 1 HEINEKEN CHINESE GRAND PRIX 2025 2025-03-23
# 3         FORMULA 1 LENOVO JAPANESE GRAND PRIX 2025  2025-04-06
# 4         FORMULA 1 GULF AIR BAHRAIN GRAND PRIX 2025 2025-04-13
#
#                EventName        EventFormat    Session1  \
# 0     Pre-Season Testing            testing  Practice 1
# 1  Australian Grand Prix       conventional  Practice 1
# 2     Chinese Grand Prix  sprint_qualifying  Practice 1
# 3    Japanese Grand Prix       conventional  Practice 1
# 4     Bahrain Grand Prix       conventional  Practice 1
#
# ...

# %%
melbourne = session25.get_event_by_round(1)
melbourne.head()
# Out:
# RoundNumber                                                          1
# Country                                                      Australia
# Location                                                     Melbourne
# OfficialEventName    FORMULA 1 LOUIS VUITTON AUSTRALIAN GRAND PRIX ...
# EventDate                                          2025-03-16 00:00:00
# Name: 1, dtype: object

# %%
melbourneRace = melbourne.get_race()

# %%
melbourneRace.load()
# Out:
# core           INFO 	Loading data for Australian Grand Prix - Race [v3.7.0]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for lap_count. Loading data...
# _api           INFO 	Fetching lap count data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# ...

# %%
melbourneRace.results
# Out:
#    DriverNumber BroadcastName Abbreviation        DriverId         TeamName  \
# 4             4      L NORRIS          NOR          norris          McLaren
# 1             1  M VERSTAPPEN          VER  max_verstappen  Red Bull Racing
# 63           63     G RUSSELL          RUS         russell         Mercedes
# 12           12   A ANTONELLI          ANT       antonelli         Mercedes
# 23           23       A ALBON          ALB           albon         Williams
# 18           18      L STROLL          STR          stroll     Aston Martin
# 27           27  N HULKENBERG          HUL      hulkenberg      Kick Sauber
# 16           16     C LECLERC          LEC         leclerc          Ferrari
# 81           81     O PIASTRI          PIA         piastri          McLaren
# 44           44    L HAMILTON          HAM        hamilton          Ferrari
# 10           10       P GASLY          GAS           gasly           Alpine
# ...

# %%
lapData = melbourneRace.laps

# %%
lapData.info()
# Out:
# <class 'fastf1.core.Laps'>
# RangeIndex: 927 entries, 0 to 926
# Data columns (total 31 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Time                927 non-null    timedelta64[ns]
#  1   Driver              927 non-null    object
#  2   DriverNumber        927 non-null    object
#  3   LapTime             858 non-null    timedelta64[ns]
#  4   LapNumber           927 non-null    float64
#  5   Stint               927 non-null    float64
#  6   PitOutTime          84 non-null     timedelta64[ns]
#  7   PitInTime           82 non-null     timedelta64[ns]
#  8   Sector1Time         904 non-null    timedelta64[ns]
#  9   Sector2Time         921 non-null    timedelta64[ns]
#  10  Sector3Time         920 non-null    timedelta64[ns]
#  11  Sector1SessionTime  903 non-null    timedelta64[ns]
#  12  Sector2SessionTime  921 non-null    timedelta64[ns]
#  13  Sector3SessionTime  920 non-null    timedelta64[ns]
# ...

# %%
lapData.head()
# Out:
#                     Time Driver DriverNumber                LapTime  \
# 0 0 days 01:13:00.002000    VER            1 0 days 00:01:59.392000
# 1 0 days 01:15:49.358000    VER            1                    NaT
# 2 0 days 01:18:31.526000    VER            1                    NaT
# 3 0 days 01:21:07.226000    VER            1                    NaT
# 4 0 days 01:23:30.835000    VER            1 0 days 00:02:23.609000
#
#    LapNumber  Stint             PitOutTime              PitInTime  \
# 0        1.0    1.0                    NaT                    NaT
# 1        2.0    1.0                    NaT 0 days 01:15:38.205000
# 2        3.0    2.0 0 days 01:15:51.658000 0 days 01:18:20.223000
# 3        4.0    3.0 0 days 01:18:34.029000 0 days 01:20:56.543000
# 4        5.0    4.0 0 days 01:21:09.534000                    NaT
#
#              Sector1Time            Sector2Time  ... FreshTyre  \
# 0                    NaT 0 days 00:00:20.705000  ...      True
# ...

# %%
lapData.iloc[0]
# Out:
# Time                      0 days 01:13:00.002000
# Driver                                       VER
# DriverNumber                                   1
# LapTime                   0 days 00:01:59.392000
# LapNumber                                    1.0
# Stint                                        1.0
# PitOutTime                                   NaT
# PitInTime                                    NaT
# Sector1Time                                  NaT
# Sector2Time               0 days 00:00:20.705000
# Sector3Time               0 days 00:00:55.250000
# Sector1SessionTime                           NaT
# Sector2SessionTime        0 days 01:12:04.853000
# Sector3SessionTime        0 days 01:13:00.058000
# SpeedI1                                    249.0
# SpeedI2                                    292.0
# SpeedFL                                    247.0
# SpeedST                                    215.0
# IsPersonalBest                             False
# ...

# %%
lapData.iloc[5]
# Out:
# Time                      0 days 01:25:50.489000
# Driver                                       VER
# DriverNumber                                   1
# LapTime                   0 days 00:02:19.654000
# LapNumber                                    6.0
# Stint                                        4.0
# PitOutTime                                   NaT
# PitInTime                                    NaT
# Sector1Time               0 days 00:00:47.887000
# Sector2Time               0 days 00:00:33.228000
# Sector3Time               0 days 00:00:58.539000
# Sector1SessionTime        0 days 01:24:18.778000
# Sector2SessionTime        0 days 01:24:52.006000
# Sector3SessionTime        0 days 01:25:50.545000
# SpeedI1                                    158.0
# SpeedI2                                    183.0
# SpeedFL                                    208.0
# SpeedST                                    127.0
# IsPersonalBest                              True
# ...

# %%
lapData.iloc[7]
# Out:
# Time                      0 days 01:29:43.766000
# Driver                                       VER
# DriverNumber                                   1
# LapTime                   0 days 00:01:36.830000
# LapNumber                                    8.0
# Stint                                        4.0
# PitOutTime                                   NaT
# PitInTime                                    NaT
# Sector1Time               0 days 00:00:35.249000
# Sector2Time               0 days 00:00:20.145000
# Sector3Time               0 days 00:00:41.436000
# Sector1SessionTime        0 days 01:28:42.241000
# Sector2SessionTime        0 days 01:29:02.386000
# Sector3SessionTime        0 days 01:29:43.822000
# SpeedI1                                    257.0
# SpeedI2                                    297.0
# SpeedFL                                    278.0
# SpeedST                                    245.0
# IsPersonalBest                              True
# ...

# %%
lapData.info()
# Out:
# <class 'fastf1.core.Laps'>
# RangeIndex: 927 entries, 0 to 926
# Data columns (total 31 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Time                927 non-null    timedelta64[ns]
#  1   Driver              927 non-null    object
#  2   DriverNumber        927 non-null    object
#  3   LapTime             858 non-null    timedelta64[ns]
#  4   LapNumber           927 non-null    float64
#  5   Stint               927 non-null    float64
#  6   PitOutTime          84 non-null     timedelta64[ns]
#  7   PitInTime           82 non-null     timedelta64[ns]
#  8   Sector1Time         904 non-null    timedelta64[ns]
#  9   Sector2Time         921 non-null    timedelta64[ns]
#  10  Sector3Time         920 non-null    timedelta64[ns]
#  11  Sector1SessionTime  903 non-null    timedelta64[ns]
#  12  Sector2SessionTime  921 non-null    timedelta64[ns]
#  13  Sector3SessionTime  920 non-null    timedelta64[ns]
# ...

# %%
subset = lapData[["Driver","Stint","TyreLife","LapTime"]]

# %%
subset
# Out:
#     Driver  Stint  TyreLife                LapTime
# 0      VER    1.0       1.0 0 days 00:01:59.392000
# 1      VER    1.0       2.0                    NaT
# 2      VER    2.0       3.0                    NaT
# 3      VER    3.0       4.0                    NaT
# 4      VER    4.0       5.0 0 days 00:02:23.609000
# ..     ...    ...       ...                    ...
# 922    BEA    6.0       9.0 0 days 00:01:31.366000
# 923    BEA    6.0      10.0 0 days 00:01:30.490000
# 924    BEA    6.0      11.0 0 days 00:01:31.284000
# 925    BEA    6.0      12.0 0 days 00:01:30.226000
# 926    BEA    6.0      13.0 0 days 00:01:30.553000
#
# [927 rows x 4 columns]

# %%
ver = lapData.pick_driver('VER')
print(ver[ver['LapTime'].isna()][['LapNumber','Stint','PitOutTime','PitInTime','FastF1Generated']])
# Out:
#     LapNumber  Stint             PitOutTime              PitInTime  \
# 1         2.0    1.0                    NaT 0 days 01:15:38.205000
# 2         3.0    2.0 0 days 01:15:51.658000 0 days 01:18:20.223000
# 3         4.0    3.0 0 days 01:18:34.029000 0 days 01:20:56.543000
# 36       37.0    5.0                    NaT                    NaT
#
#     FastF1Generated
# 1             False
# 2             False
# 3             False
# 36            False
